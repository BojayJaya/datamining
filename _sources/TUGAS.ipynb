# %% [markdown]
# # **Tugas DATA MINING**

# %% [markdown]
# # Tugas 1

# %%
print('a')
# Out:
# a

# %% [markdown]
# # Tugas 2

# %%
print('b')
# Out:
# b

# %% [markdown]
# # Tugas 3

# %%
print('c')
# Out:
# c
